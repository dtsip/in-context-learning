# %% [markdown]
# # Kaggle Running Notebook

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Cloning

# %%
# !git clone https://github.com/nelson-lojo/in-context-learning.git
# !mv in-context-learning/* .
# !rm -r in-context-learning
# Out:
# Cloning into 'in-context-learning'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 86 (delta 34), reused 36 (delta 18), pack-reused 26
# Receiving objects: 100% (86/86), 631.65 KiB | 9.57 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# #### Installing

# %%
# !conda env create -f environment.yml
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (repodata.json): / WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# Downloading and Extracting Packages
# ld_impl_linux-64-2.3 | 654 KB    |                                       |   0%
# python-3.8.12        | 18.3 MB   |                                       |   0%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |                                       |   0%
#
#
# ca-certificates-2023 | 123 KB    |                                       |   0%
#
#
#
# _openmp_mutex-5.1    | 21 KB     |                                       |   0%
#
#
#
#
# libgomp-11.2.0       | 474 KB    |                                       |   0%
#
#
#
#
#
# typing_extensions-4. | 55 KB     |                                       |   0%
#
#
#
#
#
#
# readline-8.2         | 357 KB    |                                       |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  |                                       |   0%
#
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pip-21.2.4           | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.41.2         | 108 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2022.1. | 4.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.2             | 642 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 864 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# setuptools-68.0.0    | 927 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# ca-certificates-2023 | 123 KB    | ####8                                 |  13%
#
# ld_impl_linux-64-2.3 | 654 KB    | 9                                     |   2%
#
#
#
# _openmp_mutex-5.1    | 21 KB     | ############################4         |  77%
# python-3.8.12        | 18.3 MB   |                                       |   0%
#
#
#
#
# libgomp-11.2.0       | 474 KB    | #2                                    |   3%
#
#
#
#
#
# typing_extensions-4. | 55 KB     | ##########7                           |  29%
#
#
# ca-certificates-2023 | 123 KB    | ##################################### | 100%
#
#
#
#
#
#
# readline-8.2         | 357 KB    | #6                                    |   4%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ##########5                           |  29%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  |                                       |   0%
# python-3.8.12        | 18.3 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | 6                                     |   2%
#
#
#
#
#
# typing_extensions-4. | 55 KB     | ##################################### | 100%
#
#
#
#
#
# typing_extensions-4. | 55 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | 1                                     |   1%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | #####################9                |  59%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | 4                                     |   1%
# python-3.8.12        | 18.3 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | ###################8                  |  54%
#
#
#
# _openmp_mutex-5.1    | 21 KB     | ##################################### | 100%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ##################################5   |  93%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | 8                                     |   2%
# python-3.8.12        | 18.3 MB   | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  |                                       |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# pip-21.2.4           | 1.8 MB    | 3                                     |   1%
# python-3.8.12        | 18.3 MB   | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 1                                     |   0%
#
#
#
#
# libgomp-11.2.0       | 474 KB    | ##################################### | 100%
#
#
#
#
# libgomp-11.2.0       | 474 KB    | ##################################### | 100%
#
#
#
#
#
#
# readline-8.2         | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
# readline-8.2         | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.41.2         | 108 KB    | #####4                                |  15%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# pip-21.2.4           | 1.8 MB    | ############################4         |  77%
# python-3.8.12        | 18.3 MB   | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2022.1. | 4.5 MB    | 1                                     |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##1                                   |   6%
# python-3.8.12        | 18.3 MB   | #################5                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2022.1. | 4.5 MB    | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.2             | 642 KB    | 9                                     |   2%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##6                                   |   7%
# python-3.8.12        | 18.3 MB   | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2022.1. | 4.5 MB    | ###########################1          |  73%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 864 KB    | 6                                     |   2%
# python-3.8.12        | 18.3 MB   | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# setuptools-68.0.0    | 927 KB    | 6                                     |   2%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###6                                  |  10%
# python-3.8.12        | 18.3 MB   | ###########################5          |  75%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   |                                       |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ####1                                 |  11%
# python-3.8.12        | 18.3 MB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   |                                       |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ####5                                 |  12%
# python-3.8.12        | 18.3 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 1                                     |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 1                                     |   0%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #1                                    |   3%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 2                                     |   1%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 2                                     |   1%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 3                                     |   1%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 4                                     |   1%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 4                                     |   1%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 5                                     |   1%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 6                                     |   2%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##                                    |   5%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##########                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##2                                   |   6%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 8                                     |   2%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##########9                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.41.2         | 108 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.41.2         | 108 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##4                                   |   7%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##5                                   |   7%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##6                                   |   7%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##7                                   |   8%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ############7                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###                                   |   8%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###1                                  |   8%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###############3                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###5                                  |   9%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###############9                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###6                                  |  10%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.2             | 642 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.2             | 642 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #6                                    |   5%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #7                                    |   5%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####1                                 |  11%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####3                                 |  12%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####4                                 |  12%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####6                                 |  12%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####7                                 |  13%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####9                                 |  13%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####                                 |  14%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2022.1. | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####2                                |  14%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 864 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 864 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####3                                |  14%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####4                                |  15%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####6                                |  15%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ########################8             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####7                                |  16%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####8                                |  16%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##7                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######                                |  16%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######1                               |  17%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######3                               |  17%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###########################8          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######4                               |  17%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######5                               |  18%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# pip-21.2.4           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######7                               |  18%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######8                               |  19%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######                               |  19%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######1                              |  19%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###############################2      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######2                              |  20%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###5                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######4                              |  20%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ################################3     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######5                              |  20%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# setuptools-68.0.0    | 927 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# setuptools-68.0.0    | 927 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######6                              |  21%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######8                              |  21%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######9                              |  21%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########                              |  22%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########2                             |  22%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########3                             |  23%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########4                             |  23%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########4                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########                            |  27%
#
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########2                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########8                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####5                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####7                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###########6                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######1                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############7                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######6                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######8                               |  19%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###############6                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######9                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########3                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ################7                     |  45%
# python-3.8.12        | 18.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #################5                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #################9                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########4                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####################1                 |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##########1                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##########8                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ######################7               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######################2              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #########################6            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########################            |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############1                        |  35%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###########################5          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############9                       |  41%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############6                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###############################6      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #################################4    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #################5                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##################                    |  49%
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###################4                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####################2                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ######################6               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######################4              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #######################8              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########################2             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########################             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############################6      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Collecting qtconsole
#   Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting notebook
#   Downloading notebook-7.0.6-py3-none-any.whl (4.0 MB)
# Collecting packaging>=20.0
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.45.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.1.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.6 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Collecting gin-config==0.3.0
#   Downloading gin_config-0.3.0-py3-none-any.whl (44 kB)
# Collecting pyyaml==5.4
#   Downloading PyYAML-5.4-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# Collecting cytoolz==0.11.0
#   Downloading cytoolz-0.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
# Collecting toposort==1.5
#   Downloading toposort-1.5-py2.py3-none-any.whl (7.6 kB)
# Collecting munch==2.5.0
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting Cerberus==1.3.2
#   Downloading Cerberus-1.3.2.tar.gz (52 kB)
# Collecting funcy==1.15
#   Downloading funcy-1.15-py2.py3-none-any.whl (32 kB)
# Collecting scipy>=1.1.0
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Collecting joblib>=0.11
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.15.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
# Collecting filelock
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2023.10.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
# Requirement already satisfied: setuptools in /opt/conda/envs/in-context-learning/lib/python3.8/site-packages (from Cerberus==1.3.2->quinine==0.3.0->-r /kaggle/working/condaenv.glmc2cu1.requirements.txt (line 5)) (68.0.0)
# Collecting toolz>=0.8.0
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting six>=1.10.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/in-context-learning/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.17.0->-r /kaggle/working/condaenv.glmc2cu1.requirements.txt (line 9)) (4.7.1)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-8.6.0-py3-none-any.whl (105 kB)
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
# Collecting psutil
#   Downloading psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# Collecting traitlets>=5.4.0
#   Downloading traitlets-5.14.0-py3-none-any.whl (85 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.8-py3-none-any.whl (5.3 kB)
# Collecting ipython>=7.23.1
#   Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
# Collecting comm>=0.1.1
#   Downloading comm-0.2.0-py3-none-any.whl (7.0 kB)
# Collecting pyzmq>=20
#   Downloading pyzmq-25.1.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Collecting tornado>=6.1
#   Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Collecting matplotlib-inline>=0.1
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.5.0-py3-none-any.whl (28 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30
#   Downloading prompt_toolkit-3.0.41-py3-none-any.whl (385 kB)
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting pexpect>4.3
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Collecting pygments>=2.4.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jedi>=0.16
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Collecting stack-data
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting parso<0.9.0,>=0.8.3
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Collecting importlib-metadata>=4.8.3
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.0.0-py3-none-any.whl (17 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Collecting widgetsnbextension~=4.0.9
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
# Collecting jupyterlab-widgets~=3.0.9
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
# Collecting bleach!=5.0.0
#   Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting nbformat>=5.7
#   Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.9.0-py3-none-any.whl (24 kB)
# Collecting jinja2>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting markupsafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.19.0-py3-none-any.whl (23 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.11.2-py3-none-any.whl (17 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.31.1-py3-none-any.whl (25 kB)
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.11.1-py3-none-any.whl (380 kB)
# Collecting jupyterlab-server<3,>=2.22.1
#   Downloading jupyterlab_server-2.25.2-py3-none-any.whl (58 kB)
# Collecting notebook-shim<0.3,>=0.2
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting jupyterlab<5,>=4.0.2
#   Downloading jupyterlab-4.0.9-py3-none-any.whl (9.2 MB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.19.0-py3-none-any.whl (54 kB)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting overrides
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.6.4-py3-none-any.whl (57 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting anyio>=3.1.0
#   Downloading anyio-4.1.0-py3-none-any.whl (83 kB)
# Collecting jupyter-events>=0.9.0
#   Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.0-py3-none-any.whl (14 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting idna>=2.8
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.1-py3-none-any.whl (66 kB)
# Collecting tomli
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting babel>=2.10
#   Downloading Babel-2.13.1-py3-none-any.whl (10.1 MB)
# Collecting json5>=0.9.0
#   Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.16.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (444 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Collecting qtpy>=2.4.0
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
# Collecting click
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Collecting executing>=1.2.0
#   Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Building wheels for collected packages: Cerberus
#   Building wheel for Cerberus (setup.py): started
#   Building wheel for Cerberus (setup.py): finished with status 'done'
#   Created wheel for Cerberus: filename=Cerberus-1.3.2-py3-none-any.whl size=54354 sha256=e40eccfc09eb15b730f13f4559645c3444eb03404a503bf338247aa5f49b3189
#   Stored in directory: /root/.cache/pip/wheels/ae/34/69/a4de22183e8aa2539ba66b3ed344dab74783d8d43fea2a5816
# Successfully built Cerberus
# Installing collected packages: zipp, rpds-py, attrs, six, referencing, importlib-resources, types-python-dateutil, traitlets, python-dateutil, platformdirs, pkgutil-resolve-name, jsonschema-specifications, tornado, pyzmq, pycparser, jupyter-core, jsonschema, importlib-metadata, fastjsonschema, arrow, webencodings, webcolors, uri-template, soupsieve, rfc3986-validator, rfc3339-validator, ptyprocess, nbformat, markupsafe, jupyter-client, jsonpointer, isoduration, idna, fqdn, cffi, wcwidth, tinycss2, terminado, sniffio, pyyaml, python-json-logger, pygments, pure-eval, parso, pandocfilters, packaging, nbclient, mistune, jupyterlab-pygments, jinja2, executing, exceptiongroup, defusedxml, bleach, beautifulsoup4, asttokens, argon2-cffi-bindings, websocket-client, urllib3, stack-data, send2trash, pytz, prompt-toolkit, prometheus-client, pickleshare, pexpect, overrides, nbconvert, matplotlib-inline, jupyter-server-terminals, jupyter-events, jedi, decorator, charset-normalizer, certifi, backcall, argon2-cffi, anyio, requests, psutil, nest-asyncio, jupyter-server, json5, ipython, debugpy, comm, babel, tqdm, tomli, notebook-shim, jupyterlab-server, jupyter-lsp, ipykernel, fsspec, filelock, async-lru, widgetsnbextension, toolz, regex, qtpy, pyparsing, pillow, numpy, kiwisolver, jupyterlab-widgets, jupyterlab, joblib, huggingface-hub, fonttools, cycler, click, toposort, tokenizers, threadpoolctl, scipy, sacremoses, qtconsole, pandas, notebook, munch, matplotlib, jupyter-console, ipywidgets, gin-config, funcy, cytoolz, Cerberus, xgboost, transformers, seaborn, scikit-learn, quinine, protobuf, jupyter
# Successfully installed Cerberus-1.3.2 anyio-4.1.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 asttokens-2.4.1 async-lru-2.0.4 attrs-23.1.0 babel-2.13.1 backcall-0.2.0 beautifulsoup4-4.12.2 bleach-6.1.0 certifi-2023.11.17 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 comm-0.2.0 cycler-0.12.1 cytoolz-0.11.0 debugpy-1.8.0 decorator-5.1.1 defusedxml-0.7.1 exceptiongroup-1.2.0 executing-2.0.1 fastjsonschema-2.19.0 filelock-3.13.1 fonttools-4.45.1 fqdn-1.5.1 fsspec-2023.10.0 funcy-1.15 gin-config-0.3.0 huggingface-hub-0.19.4 idna-3.6 importlib-metadata-6.8.0 importlib-resources-6.1.1 ipykernel-6.27.1 ipython-8.12.3 ipywidgets-8.1.1 isoduration-20.11.0 jedi-0.19.1 jinja2-3.1.2 joblib-1.3.2 json5-0.9.14 jsonpointer-2.4 jsonschema-4.20.0 jsonschema-specifications-2023.11.2 jupyter-1.0.0 jupyter-client-8.6.0 jupyter-console-6.6.3 jupyter-core-5.5.0 jupyter-events-0.9.0 jupyter-lsp-2.2.1 jupyter-server-2.11.1 jupyter-server-terminals-0.4.4 jupyterlab-4.0.9 jupyterlab-pygments-0.3.0 jupyterlab-server-2.25.2 jupyterlab-widgets-3.0.9 kiwisolver-1.4.5 markupsafe-2.1.3 matplotlib-3.5.2 matplotlib-inline-0.1.6 mistune-3.0.2 munch-2.5.0 nbclient-0.9.0 nbconvert-7.11.0 nbformat-5.9.2 nest-asyncio-1.5.8 notebook-7.0.6 notebook-shim-0.2.3 numpy-1.22.3 overrides-7.4.0 packaging-23.2 pandas-1.4.2 pandocfilters-1.5.0 parso-0.8.3 pexpect-4.9.0 pickleshare-0.7.5 pillow-10.1.0 pkgutil-resolve-name-1.3.10 platformdirs-4.0.0 prometheus-client-0.19.0 prompt-toolkit-3.0.41 protobuf-3.20.1 psutil-5.9.6 ptyprocess-0.7.0 pure-eval-0.2.2 pycparser-2.21 pygments-2.17.2 pyparsing-3.1.1 python-dateutil-2.8.2 python-json-logger-2.0.7 pytz-2023.3.post1 pyyaml-5.4 pyzmq-25.1.1 qtconsole-5.5.1 qtpy-2.4.1 quinine-0.3.0 referencing-0.31.1 regex-2023.10.3 requests-2.31.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.13.2 sacremoses-0.1.1 scikit-learn-1.0.2 scipy-1.10.1 seaborn-0.11.2 send2trash-1.8.2 six-1.16.0 sniffio-1.3.0 soupsieve-2.5 stack-data-0.6.3 terminado-0.18.0 threadpoolctl-3.2.0 tinycss2-1.2.1 tokenizers-0.15.0 tomli-2.0.1 toolz-0.12.0 toposort-1.5 tornado-6.4 tqdm-4.64.0 traitlets-5.14.0 transformers-4.17.0 types-python-dateutil-2.8.19.14 uri-template-1.3.0 urllib3-2.1.0 wcwidth-0.2.12 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.4 widgetsnbextension-4.0.9 xgboost-1.6.1 zipp-3.17.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate in-context-learning
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda clean -ya
# Out:
# Will remove 26 (1.73 GB) tarball(s).
# Will remove 1 index cache(s).
# Will remove 25 (270.0 MB) package(s).
# There are no tempfile(s) to remove.
# There are no logfile(s) to remove.

# %%
import os
old_path = os.environ["PATH"]
env_name = "in-context-learning"
new_path = f"/opt/conda/envs/{env_name}/bin:{old_path}"

# %%
# %env PATH=$new_path
# Out:
# env: PATH=/opt/conda/envs/in-context-learning/bin:/opt/bin:/opt/conda/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# %%
# %%writefile main.py

import sys

if __name__ == "__main__":
    print(sys.path)
# Out:
# Writing main.py

# %%
# !/opt/conda/envs/{env_name}/bin/python ./main.py
# Out:
# ['/kaggle/working', '/kaggle/lib/kagglegym', '/kaggle/lib', '/opt/conda/envs/in-context-learning/lib/python38.zip', '/opt/conda/envs/in-context-learning/lib/python3.8', '/opt/conda/envs/in-context-learning/lib/python3.8/lib-dynload', '/opt/conda/envs/in-context-learning/lib/python3.8/site-packages']

# %% [markdown]
# ## Training

# %%
# !python src/train.py --config src/conf/toy.yaml
# Out:
# Running with: Quinfig
# -------
# config: src/conf/toy.yaml
# inherit:
# - /kaggle/working/src/conf/models/standard.yaml
# - /kaggle/working/src/conf/wandb.yaml
# model:
#   family: gpt2
#   n_dims: 5
#   n_embd: 256
#   n_head: 8
#   n_layer: 12
#   n_positions: 11
# out_dir: ../models/linear_regression
# test_run: false
# training:
#   batch_size: 64
#   curriculum:
#     dims:
#       end: 5
#       inc: 1
#       interval: 2000
#       start: 5
#     points:
#       end: 11
#       inc: 2
#       interval: 2000
#       start: 11
#   data: gaussian
#   keep_every_steps: 100000
#   learning_rate: 0.0001
#   num_tasks: null
#   num_training_examples: null
#   resume_id: null
#   save_every_steps: 1000
#   task: linear_regression
#   task_kwargs: {}
#   train_steps: 5001
# wandb:
#   entity: your-entity
#   log_every_steps: 100
#   name: linear_regression_toy
#   notes: ''
#   project: in-context-training
#
# loss 1.7360455989837646: 100%|██████████████| 5001/5001 [03:13<00:00, 25.82it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:21<00:00,  1.43s/it]
